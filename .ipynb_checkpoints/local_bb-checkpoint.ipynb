# %%
import networkx as nx
import neo4j
from neo4j import GraphDatabase, basic_auth
import json
import matplotlib.pyplot as plt
import pandas as pd

# %%
driver = neo4j.GraphDatabase.driver(
    "neo4j://localhost:7687", auth=("neo4j", "flowerbwoy"))

# %%
df = pd.read_csv('local_black.csv')
df
# Out:
#          #                             Name Black Owned Confirmed?  \
# 0      1.0                  Rock City Pizza              Confirmed
# 1      4.0                   TamBos Kitchen            Unconfirmed
# 2      5.0              Restaurante Cesaria              Confirmed
# 3      6.0                     Bred Gourmet              Confirmed
# 4      7.0  Darryl's Corner Bar and Kitchen              Confirmed
# ..     ...                              ...                    ...
# 150  151.0                    Brazo Fuerte             Unconfirmed
# 151  152.0                    Viva Mi Arepa            Unconfirmed
# 152  153.0               Belmont Vegetarian            Unconfirmed
# 153  154.0                    Fatima's Cafe            Unconfirmed
# 154  155.0                      Anokye Krom            Unconfirmed
#
#              Area              Direct Venmo/Donation Option/Giftcard  \
# 0         Allston                                                NaN
# 1            Avon                                                NaN
# 2          Boston                                                NaN
# 3          Boston  http://www.bredgourmet.com/shopbred/bred-gift-...
# 4          Boston  https://www.toasttab.com/darryls-corner-bar-ki...
# ..            ...                                                ...
# 150     Watertown                                                NaN
# 151  West Roxbury                                                NaN
# 152     Worcester                                                NaN
# 153     Worcester                                                NaN
# 154     Worcester                                                NaN
#
#            Cuisine/ Shop type  \
# 0                    American
# 1                West African
# 2       African/ Cape Verdean
# 3                    American
# 4                    American
# ..                        ...
# 150                  Brewery
# 151       Haitian/Venezuelan
# 152                 Caribbean
# 153  East African / Ethiopian
# 154  Ghanaian / West African
#
#                                                Website  \
# 0                        https://rockcitypizzeria.com/
# 1                           https://tamboskitchen.com/
# 2                   https://www.restaurantcesaria.com/
# 3                          http://www.bredgourmet.com/
# 4                               http://dcbkboston.com/
# ..                                                 ...
# 150               http://brazo-fuerte.squarespace.com/
# 151             https://www.vivamiareparestaurant.com/
# 152       https://www.belmontvegetarian.com/index.html
# 153                        http://www.fatimascafe.com/
# 154  https://www.doordash.com/store/anokye-krom-afr...
#
#                                            Instagram  \
# 0    https://www.instagram.com/rockcitypizzaallston/
# 1           https://www.instagram.com/tamboskitchen/
# 2      https://www.instagram.com/restaurantecesaria/
# 3             https://www.instagram.com/bredgourmet/
# 4              https://www.instagram.com/dcbkboston/
# ..                                               ...
# 150       https://www.instagram.com/brazofuertebeer/
# 151                                              NaN
# 152    https://www.instagram.com/belmontvegetarian_/
# 153                                              NaN
# 154                                              NaN
#
#                                                     FB  \
# 0           https://www.facebook.com/RockCityPizzeria/
# 1              https://www.facebook.com/tamboskitchen/
# 2          https://www.facebook.com/RestaurantCesaria/
# 3                https://www.facebook.com/BREDGOURMET/
# 4                 https://www.facebook.com/DCBKBoston/
# ..                                                 ...
# 150          https://www.facebook.com/brazofuertebeer/
# 151                                                NaN
# 152  https://www.facebook.com/BelmontVegetarianRest...
# 153                                                NaN
# 154  https://www.facebook.com/pages/Anokye-Krom/131...
#
#                                  Twitter  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3        https://twitter.com/BredGourmet
# 4         https://twitter.com/DCBKBoston
# ..                                   ...
# 150  https://twitter.com/BrazoFuerteBeer
# 151                                  NaN
# 152      https://twitter.com/belmontveg1
# 153                                  NaN
# 154                                  NaN
#
#                                                YouTube  \
# 0                                                  NaN
# 1    https://www.youtube.com/channel/UCfh-OI9DB3Wtm...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
#
#                 Delivery Options                          Combined Address  \
# 0                            NaN        568 Cambridge St, Boston, MA 02134
# 1                         Local              490 W Main St, Avon, MA 02322
# 2    Doordash, grubhub, ubereats          266 Bowdoin St, Boston, MA 02122
# 3                        Grubhub     2255 Dorchester Ave, Boston, MA 02124
# 4                        Grubhub        604 Columbus Ave, Boston, MA 02118
# ..                           ...                                       ...
# 150                        local                                       NaN
# 151           Grubhub, uber eats  5197 Washington Street\nBoston, MA 02132
# 152                      Pick up       157 Belmont St, Worcester, MA 01605
# 153            Pick up, catering        43 West Boylston St, Worcester, MA
# 154                     Doordash      687 Millbury St, Worcester, MA 01607
#
#                      Street Address       City State Zipcode Email Address  \
# 0                  568 Cambridge St    Allston    MA    2134           NaN
# 1                     490 W Main St       Avon    MA    2322           NaN
# 2                    266 Bowdoin St     Boston    MA    2122           NaN
# 3               2255 Dorchester Ave     Boston    MA    2124           NaN
# 4                  604 Columbus Ave     Boston    MA    2118           NaN
# ..                              ...        ...   ...     ...           ...
# 150                             NaN        NaN    MA     NaN           NaN
# 151  5197 Washington Street\nBoston   MA 02132    MA    2132           NaN
# 152                  157 Belmont St  Worcester    MA    1605           NaN
# 153             43 West Boylston St  Worcester    MA     NaN           NaN
# 154                 687 Millbury St  Worcester    MA    1607           NaN
#
#           Phone
# 0           NaN
# 1           NaN
# 2           NaN
# 3    6176980103
# 4    6175361100
# ..          ...
# 150         NaN
# 151         NaN
# 152         NaN
# 153         NaN
# 154         NaN
#
# [155 rows x 19 columns]

# %%
def build_graph():
    driver.close()
    with driver.session() as session:
        cypher1 = """
            LOAD CSV WITH HEADERS FROM 'file:///local_black.csv' AS Line
            UNWIND split(Line.`Cuisine/ Shop type`, ' / ') AS type
            MERGE (s:Type {name: type})
            """
        cypher2 = """
            LOAD CSV WITH HEADERS FROM 'file:///local_black.csv' AS Line
            CREATE(:Business {id: toInteger(Line.`#`),
                              name: Line.Name, 
                              confirmed: Line.`Black Owned Confirmed?`,
                              area: Line.Area,
                              direct_aid: Line.`Direct Venmo/Donation Option/Giftcard`,
                              cuisine_or_type: Line.`Cuisine/ Shop type`,
                              url: Line.Website,
                              instagram: Line.Instagram,
                              fb: Line.FB,
                              twitter: Line.Twitter,
                              delivery: Line.`Delivery Options`,
                              address: Line.`Combined Address`,
                              phone: Line.Phone})      
        """
        cypher3 = """
            MATCH(n) WHERE(n.confirmed = 'Unconfirmed') DELETE n
        """
        session.run(cypher1)
        session.run(cypher2)

    driver.close()

def map_cuisine():
    
    cuisines = []
    driver.close()
    with driver.session() as session2:
        result = session2.run('MATCH(a:Type) RETURN a.name as name')
        for line in result:
            cuisines.append(line['name'])
    
    
    #c_set = set([n for n in df['Cuisine/ Shop type']])
    print(cuisines)
    c_set = set([n for n in cuisines])
    for c in c_set:
        for index, row in df.iterrows():
            if c in str(row['Cuisine/ Shop type']):
                #driver.session().run("MERGE(:Type {name: $node2})", node2=c)
                #driver.close()
                driver.session().run("""
                    MATCH(a:Business),(b:Type) 
                    WHERE a.name = $node1 AND b.name = $node2
                    MERGE (b)-[r:RELTYPE]->(a)
                """, node1=row['Name'], node2=c)
                driver.close()
                
    driver.close()
    
def create_node(session, driver, row):
    cypher = """
        MERGE (n:Business {name: $row.Name}, {Black}),
    
    """
    session.run("MERGE (n:Business {name: $node})", node=node)

def create_relationship(session, tx, node1, node2):
    session.run("""
        MATCH (a:Topic),(b:Topic) 
        WHERE a.name = $node1 AND b.name = $node2 
        MERGE (a)-[r:IS_RELATED_TO]->(b)""", node1=node1, node2=node2)

def clear_database():
    query = """
        MATCH (n)
        DETACH DELETE n
        """
    with driver.session() as session:
        session.run(query)

# %%
driver.close()
clear_database()
build_graph()
map_cuisine()
#map_cuisine()
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# <ipython-input-66-3aed446351fc> in <module>
#       1 driver.close()
#       2 clear_database()
# ----> 3 build_graph()
#       4 map_cuisine()
#       5 #map_cuisine()
#
# <ipython-input-65-60ac538358d6> in build_graph()
#      27             MATCH(n) WHERE(n.confirmed = 'Unconfirmed') DELETE n
#      28         """
# ---> 29         session.run(cypher1)
#      30         session.run(cypher2)
#      31         session.run(cypher3)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neo4j/work/simple.py in run(self, query, parameters, **kwparameters)
#     215
#     216         self._autoResult = Result(cx, hydrant, self._config.fetch_size, self._result_closed)
# --> 217         self._autoResult._run(query, parameters, self._config.database, self._config.default_access_mode, self._bookmarks, **kwparameters)
#     218
#     219         return self._autoResult
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neo4j/work/result.py in _run(self, query, parameters, db, access_mode, bookmarks, **kwparameters)
#      99         self._pull()
#     100         self._connection.send_all()
# --> 101         self._attach()
#     102
#     103     def _pull(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neo4j/work/result.py in _attach(self)
#     200         if self._closed is False:
#     201             while self._attached is False:
# --> 202                 self._connection.fetch_message()
#     203
#     204     def _buffer_all(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neo4j/io/_bolt4x0.py in fetch_message(self)
#     328             log.debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
#     329             try:
# --> 330                 response.on_failure(summary_metadata or {})
#     331             except (ServiceUnavailable, DatabaseUnavailable):
#     332                 if self.pool:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/neo4j/io/_bolt4x0.py in on_failure(self, metadata)
#     516         if callable(handler):
#     517             handler()
# --> 518         raise Neo4jError.hydrate(**metadata)
#     519
#     520     def on_ignored(self, metadata=None):
#
# CypherSyntaxError: Invalid input 'H': expected 'i/I' (line 5, column 14 (offset: 194))
# "            WHERE NOT Line.`Black Owned Confirmed?` = 'Unconfirmed'"
#               ^
